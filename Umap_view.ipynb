# %%
from Umap_images import *
import os

# %% [raw]
# Real data

# %%
image_data, labels_val, labels_all, type_dict = load_data_and_labels(validated_images_dir=os.path.join('RGCtypes_validated_473','train_subset'), 
                                                                     unvalidated_images_dir='unvalidated_subset')

plot_umap(image_data,labels_val,labels_all,type_dict,supervised='semi',plotpoints='unvalidated')

# %% [raw]
# Real data: plot validated set

# %%
plot_umap(image_data,labels_val,labels_all,type_dict,supervised='semi',plotpoints='validated')

# %% [raw]
# Through auto-encoder: generated = test

# %%
image_data, labels_val, labels_all, type_dict = load_data_and_labels(unvalidated_images_dir='generated_latdim3_varScale_0.0', 
                                                                     validated_images_dir=os.path.join('RGCtypes_validated_473','train_subset'))

plot_umap(image_data,labels_val,labels_all,type_dict,supervised='semi',plotpoints='unvalidated')

# %% [raw]
# Through auto-encoder: generated = train

# %%
image_data, labels_val, labels_all, type_dict = load_data_and_labels(validated_images_dir='generated_latdim3_varScale_0.0', 
                                                                     unvalidated_images_dir='unvalidated_subset')
plot_umap(image_data,labels_val,labels_all,type_dict,supervised='semi',plotpoints='unvalidated')

# %% [raw]
# 100 draws with variance = .05: generated = test

# %%
image_data, labels_val, labels_all, type_dict = load_data_and_labels(unvalidated_images_dir='generated_latdim3_varScale_0.05', 
                                                                     validated_images_dir=os.path.join('RGCtypes_validated_473','train_subset'))

plot_umap(image_data,labels_val,labels_all,type_dict,supervised='semi',plotpoints='unvalidated')

# %% [raw]
# 100 draws with variance = .05: generated = train

# %%
image_data, labels_val, labels_all, type_dict = load_data_and_labels(validated_images_dir='generated_latdim3_varScale_0.05', 
                                                                     unvalidated_images_dir='unvalidated_subset')

plot_umap(image_data,labels_val,labels_all,type_dict,supervised='semi',plotpoints='unvalidated')

# %% [raw]
# 100 draws with variance = .02: generated = test

# %%
image_data, labels_val, labels_all, type_dict = load_data_and_labels(unvalidated_images_dir='generated_latdim3_varScale_0.02', 
                                                                     validated_images_dir=os.path.join('RGCtypes_validated_473','train_subset'))

plot_umap(image_data,labels_val,labels_all,type_dict,supervised='semi',plotpoints='unvalidated')

# %% [raw]
# 100 draws with variance = .02: generated = train

# %%
image_data, labels_val, labels_all, type_dict = load_data_and_labels(validated_images_dir='generated_latdim3_varScale_0.02', 
                                                                     unvalidated_images_dir='unvalidated_subset')

plot_umap(image_data,labels_val,labels_all,type_dict,supervised='semi',plotpoints='unvalidated')
